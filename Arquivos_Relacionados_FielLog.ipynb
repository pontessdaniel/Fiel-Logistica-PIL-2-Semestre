# %%
import pandas as pd

# %%
import numpy as np

# %%
caminho_in = '/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/'
caminho_out = '/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/'

# %%
from google.colab import drive
drive.mount('/content/drive')
df_2022= '/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/EXP_2022.csv'
df_2023= '/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/EXP_2023.csv'
df_2024= '/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/EXP_2024.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_2022 = caminho_in + 'EXP_2022.csv'

# %%
pd.read_csv(df_2022, low_memory=False, sep=';', encoding= 'UTF-8')
# Out:
#          CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  \
# 0          2022       6  85045000       11       69        MG       4
# 1          2022       4  39219019       10      586        SP       7
# 2          2022       1  44071100       16      249        SC       1
# 3          2022      11  84672100       11      521        RS       1
# 4          2022      10   8072000       10       23        RN       4
# ...         ...     ...       ...      ...      ...       ...     ...
# 1495863    2022      11  32061910       10      845        SP       7
# 1495864    2022       1  12024200       10      434        AM       1
# 1495865    2022       9  18040000       21      249        BA       1
# 1495866    2022       8  16010000       10       99        SC       1
# 1495867    2022       8  64031900       13       69        RJ       4
#
#           CO_URF  QT_ESTAT  KG_LIQUIDO   VL_FOB
# 0         817600         2        1399    19576
# 1         917500      3914        3914    12672
# 2         927800     21945     8409167  5177394
# 3         817800        10          25      487
# 4         417901     55356       55356    71511
# ...          ...       ...         ...      ...
# 1495863  1010252       975         975     5489
# 1495864   227600         4           4       26
# 1495865   517800       180      180000  1295568
# 1495866   927800      1820        1820     1930
# 1495867   817700         1           1       68
#
# [1495868 rows x 11 columns]

# %%
df_2023 = caminho_in + 'EXP_2023.csv'
with open(df_2023, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: "CO_ANO";"CO_MES";"CO_NCM";"CO_UNID";"CO_PAIS";"SG_UF_NCM";"CO_VIA";"CO_URF";"QT_ESTAT";"KG_LIQUIDO";"VL_FOB"
#
# Linha 2: "2023";"03";"84139190";"10";"160";"RJ";"04";"0817700";107365;5;20
#
# Linha 3: "2023";"12";"73182100";"10";"764";"SP";"01";"0817800";0;0;84
#
# Linha 4: "2023";"04";"84219999";"10";"040";"RS";"04";"0817600";2;2;758
#
# Linha 5: "2023";"05";"85291090";"10";"063";"RJ";"07";"1017503";1;1;275

# %%
pd.read_csv(df_2023, low_memory=False, sep=';', encoding= 'UTF-8')
# Out:
#          CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  \
# 0          2023       3  84139190       10      160        RJ       4
# 1          2023      12  73182100       10      764        SP       1
# 2          2023       4  84219999       10       40        RS       4
# 3          2023       5  85291090       10       63        RJ       7
# 4          2023      10  84825010       11       63        MG       7
# ...         ...     ...       ...      ...      ...       ...     ...
# 1563654    2023      11  64029990       13      337        RS       1
# 1563655    2023      11  85321000       11      670        RS       4
# 1563656    2023       2  20091900       10      586        PR       7
# 1563657    2023      12   9101100       10      160        MA       1
# 1563658    2023       5  42029200       11      249        RS       4
#
#           CO_URF  QT_ESTAT  KG_LIQUIDO  VL_FOB
# 0         817700    107365           5      20
# 1         817800         0           0      84
# 2         817600         2           2     758
# 3        1017503         1           1     275
# 4        1017503         2           0       9
# ...          ...       ...         ...     ...
# 1563654   817800      4284        2549   38719
# 1563655  1017801        24          13     226
# 1563656   917500     17175       17175   12457
# 1563657   317903        10          10      30
# 1563658   817700         2           6      30
#
# [1563659 rows x 11 columns]

# %%
df_2024 = caminho_in + 'EXP_2024.csv'
with open(df_2024, 'r', encoding='UTF-8') as f:
    linhas = f.readlines()
    for i in range(0, 5):
        print(f"Linha {i+1}: {linhas[i]}")
# Out:
# Linha 1: "CO_ANO";"CO_MES";"CO_NCM";"CO_UNID";"CO_PAIS";"SG_UF_NCM";"CO_VIA";"CO_URF";"QT_ESTAT";"KG_LIQUIDO";"VL_FOB"
#
# Linha 2: "2024";"04";"94036000";"11";"245";"SP";"04";"0817600";8;425;20423
#
# Linha 3: "2024";"11";"87088000";"11";"493";"SP";"01";"0817800";418615;60355;470512
#
# Linha 4: "2024";"03";"02071400";"10";"173";"SP";"01";"0817800";94080;94080;237562
#
# Linha 5: "2024";"04";"90303390";"11";"158";"MG";"01";"0817800";10;12;1704

# %%
pd.read_csv(df_2024, low_memory=False, sep=';', encoding= 'UTF-8')
# Out:
#          CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  \
# 0          2024       4  94036000       11      245        SP       4
# 1          2024      11  87088000       11      493        SP       1
# 2          2024       3   2071400       10      173        SP       1
# 3          2024       4  90303390       11      158        MG       1
# 4          2024       8  40129090       10      158        SC       4
# ...         ...     ...       ...      ...      ...       ...     ...
# 1603791    2024       5  72044900       10      361        AM       1
# 1603792    2024       8   4062000       10      845        RS       7
# 1603793    2024      12  84254200       11      589        PR       7
# 1603794    2024       4  87021000       11      589        PR       7
# 1603795    2024       5  39234000       10      158        SP       7
#
#           CO_URF  QT_ESTAT  KG_LIQUIDO   VL_FOB
# 0         817600         8         425    20423
# 1         817800    418615       60355   470512
# 2         817800     94080       94080   237562
# 3         817800        10          12     1704
# 4         817700        26          26      950
# ...          ...       ...         ...      ...
# 1603791   717800    164980      164980    44921
# 1603792  1017701       972         972    10397
# 1603793  1017503         3          32      239
# 1603794  1017503        27      494810  8127514
# 1603795  1017500         0           0       12
#
# [1603796 rows x 11 columns]

# %%
df_geral = [df_2022, df_2023, df_2024]
ANTAQ_Int = pd.DataFrame()
for df_geral in df_geral:
    df = pd.read_csv(df_geral, sep = ';')
    ANTAQ_Int = pd.concat([ANTAQ_Int, df], ignore_index=True)
df_geral = pd.DataFrame()
ANTAQ_Int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4663323 entries, 0 to 4663322
# Data columns (total 11 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      int64
#  1   CO_MES      int64
#  2   CO_NCM      int64
#  3   CO_UNID     int64
#  4   CO_PAIS     int64
#  5   SG_UF_NCM   object
#  6   CO_VIA      int64
#  7   CO_URF      int64
#  8   QT_ESTAT    int64
#  9   KG_LIQUIDO  int64
#  10  VL_FOB      int64
# dtypes: int64(10), object(1)
# memory usage: 391.4+ MB

# %%
ANTAQ_Int.head(10)
# Out:
#    CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 0    2022       6  85045000       11       69        MG       4  817600
# 1    2022       4  39219019       10      586        SP       7  917500
# 2    2022       1  44071100       16      249        SC       1  927800
# 3    2022      11  84672100       11      521        RS       1  817800
# 4    2022      10   8072000       10       23        RN       4  417901
# 5    2022       9  34013000       10      169        SP       4  817600
# 6    2022       2  40169300       10      158        SP       4  817700
# 7    2022       9  68053090       10      580        SP       1  817800
# 8    2022       1  39069019       10      493        SP       1  817800
# 9    2022       7  61071100       11      586        SP       7  917500
#
#    QT_ESTAT  KG_LIQUIDO   VL_FOB
# 0         2        1399    19576
# 1      3914        3914    12672
# 2     21945     8409167  5177394
# 3        10          25      487
# 4     55356       55356    71511
# 5      1267        1267    12848
# 6       359         359    67147
# 7       392         392     1243
# 8     18000       18000    28286
# 9     22292        1361    42077

# %%
ANTAQ_Int.tail(10)
# Out:
#          CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  \
# 4663313    2024       6   2032900       10       63        PR       7
# 4663314    2024       3  87083090       11      244        RS       4
# 4663315    2024      11   7102900       10      434        PA       1
# 4663316    2024      10  15171000       10      580        PA       1
# 4663317    2024       5  85322590       11      245        RS       4
# 4663318    2024       5  72044900       10      361        AM       1
# 4663319    2024       8   4062000       10      845        RS       7
# 4663320    2024      12  84254200       11      589        PR       7
# 4663321    2024       4  87021000       11      589        PR       7
# 4663322    2024       5  39234000       10      158        SP       7
#
#           CO_URF  QT_ESTAT  KG_LIQUIDO   VL_FOB
# 4663313   917500     23000       23000    58620
# 4663314   817600         4           5      292
# 4663315   217800        20          20       84
# 4663316   217800        10          10       18
# 4663317   817600       504          42     2039
# 4663318   717800    164980      164980    44921
# 4663319  1017701       972         972    10397
# 4663320  1017503         3          32      239
# 4663321  1017503        27      494810  8127514
# 4663322  1017500         0           0       12

# %%
#CSV Referente aos anos mesclados.
df_geral = ANTAQ_Int.to_csv(caminho_out + 'ANTAQ_Int.csv', index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
via = '/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/VIA.csv'
urf = '/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/URF.csv'
pais = '/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/PAIS.csv'
uf = '/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/UF.csv'
ncm = '/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/NCM.csv'
geral = '/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/ANTAQ_Int.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Seleção das vias principais.
mesclado1 = pd.read_csv('/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/VIA.csv', sep=';')
mesclado1['NO_VIA'] = mesclado1['NO_VIA'].astype(str).str.strip().str.upper()
vias_permitidas = ['MARITIMA', 'AEREA', 'FERROVIARIA', 'RODOVIARIA', 'DUTOS']
mesclado1 = mesclado1[mesclado1['NO_VIA'].isin(vias_permitidas)]
mesclado1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 1 to 15
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO_VIA  5 non-null      int64
#  1   NO_VIA  5 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 120.0+ bytes

# %%
mesclado2 = pd.read_csv(geral, sep=',', header=0, names=['CO_ANO', 'CO_MES', 'CO_NCM', 'CO_UNID', 'CO_PAIS', 'SG_UF_NCM', 'CO_VIA', 'CO_URF', 'QT_ESTAT', 'KG_LIQUIDO', 'VL_FOB'])
mesclado2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4663323 entries, 0 to 4663322
# Data columns (total 11 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   CO_ANO      int64
#  1   CO_MES      int64
#  2   CO_NCM      int64
#  3   CO_UNID     int64
#  4   CO_PAIS     int64
#  5   SG_UF_NCM   object
#  6   CO_VIA      int64
#  7   CO_URF      int64
#  8   QT_ESTAT    int64
#  9   KG_LIQUIDO  int64
#  10  VL_FOB      int64
# dtypes: int64(10), object(1)
# memory usage: 391.4+ MB

# %%
mesclado3 = pd.read_csv(urf, sep = ';', encoding='latin-1')
mesclado3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CO_URF  278 non-null    int64
#  1   NO_URF  278 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 4.5+ KB

# %%
mesclado4 = pd.read_csv(pais, sep = ';', encoding='latin-1')
mesclado4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281 entries, 0 to 280
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CO_PAIS        281 non-null    int64
#  1   CO_PAIS_ISON3  281 non-null    int64
#  2   CO_PAIS_ISOA3  281 non-null    object
#  3   NO_PAIS        281 non-null    object
#  4   NO_PAIS_ING    281 non-null    object
#  5   NO_PAIS_ESP    281 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 13.3+ KB

# %%
mesclado5 = pd.read_csv(uf, sep = ';', encoding='latin-1')
mesclado5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CO_UF      34 non-null     int64
#  1   SG_UF      34 non-null     object
#  2   NO_UF      34 non-null     object
#  3   NO_REGIAO  34 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.2+ KB

# %%
mesclado6 = pd.read_csv(ncm, sep = ';', encoding='latin-1')
mesclado6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13720 entries, 0 to 13719
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CO_NCM          13720 non-null  int64
#  1   CO_UNID         13720 non-null  int64
#  2   CO_SH6          13720 non-null  int64
#  3   CO_PPE          13418 non-null  float64
#  4   CO_PPI          13418 non-null  float64
#  5   CO_FAT_AGREG    13699 non-null  float64
#  6   CO_CUCI_ITEM    13720 non-null  object
#  7   CO_CGCE_N3      13720 non-null  int64
#  8   CO_SIIT         13418 non-null  float64
#  9   CO_ISIC_CLASSE  13720 non-null  int64
#  10  CO_EXP_SUBSET   13417 non-null  float64
#  11  NO_NCM_POR      13720 non-null  object
#  12  NO_NCM_ESP      13720 non-null  object
#  13  NO_NCM_ING      13720 non-null  object
# dtypes: float64(5), int64(5), object(4)
# memory usage: 1.5+ MB

# %%
print(mesclado1.columns)
print(mesclado2.columns)
print(mesclado3.columns)
print(mesclado4.columns)
print(mesclado5.columns)
print(mesclado6.columns)
# Out:
# Index(['CO_VIA', 'NO_VIA'], dtype='object')
# Index(['CO_ANO', 'CO_MES', 'CO_NCM', 'CO_UNID', 'CO_PAIS', 'SG_UF_NCM',
#        'CO_VIA', 'CO_URF', 'QT_ESTAT', 'KG_LIQUIDO', 'VL_FOB'],
#       dtype='object')
# Index(['CO_URF', 'NO_URF'], dtype='object')
# Index(['CO_PAIS', 'CO_PAIS_ISON3', 'CO_PAIS_ISOA3', 'NO_PAIS', 'NO_PAIS_ING',
#        'NO_PAIS_ESP'],
#       dtype='object')
# Index(['CO_UF', 'SG_UF', 'NO_UF', 'NO_REGIAO'], dtype='object')
# Index(['CO_NCM', 'CO_UNID', 'CO_SH6', 'CO_PPE', 'CO_PPI', 'CO_FAT_AGREG',
#        'CO_CUCI_ITEM', 'CO_CGCE_N3', 'CO_SIIT', 'CO_ISIC_CLASSE',
#        'CO_EXP_SUBSET', 'NO_NCM_POR', 'NO_NCM_ESP', 'NO_NCM_ING'],
#       dtype='object')

# %%
tabela_final = pd.merge(mesclado1, mesclado2, on='CO_VIA')
tabela_final = pd.merge(tabela_final, mesclado3, on='CO_URF')
tabela_final = pd.merge(tabela_final, mesclado4, on='CO_PAIS')
tabela_final = pd.merge(tabela_final, mesclado5, left_on='SG_UF_NCM', right_on='SG_UF')
tabela_final = pd.merge(tabela_final, mesclado6, on='CO_NCM')

# %%
# Calcula o valor agregado
tabela_final['VL_AGREGADO'] = round(tabela_final['VL_FOB'] / tabela_final['KG_LIQUIDO'], 2)

# Filtro para valores maiores que 0.001.
tabela_final = tabela_final[
    (tabela_final['VL_FOB'] != 0) &
    (tabela_final['VL_FOB'] > 0.001) &
    (tabela_final['KG_LIQUIDO'] != 0) &
    (tabela_final['KG_LIQUIDO'] > 0.001)]

tabela_final['VL_AGREGADO'] = round(tabela_final['VL_FOB'] / tabela_final['KG_LIQUIDO'], 2)

# Remove VL_AGREGADO = 0
tabela_final = tabela_final[tabela_final['VL_AGREGADO'] != 0]
tabela_final = tabela_final.dropna()
print(tabela_final.head())
# Out:
#    CO_VIA    NO_VIA  CO_ANO  CO_MES    CO_NCM  CO_UNID_x  CO_PAIS SG_UF_NCM  \
# 0       1  MARITIMA    2022       1  44071100         16      249        SC
# 1       1  MARITIMA    2022      11  84672100         11      521        RS
# 2       1  MARITIMA    2022       9  68053090         10      580        SP
# 3       1  MARITIMA    2022       1  39069019         10      493        SP
# 4       1  MARITIMA    2022       9   8071100         10      628        RN
#
#    CO_URF  QT_ESTAT  ...  CO_FAT_AGREG  CO_CUCI_ITEM CO_CGCE_N3  CO_SIIT  \
# 0  927800     21945  ...           2.0          2482        240   4000.0
# 1  817800        10  ...           3.0         77841        110   2000.0
# 2  817800       392  ...           3.0         66329        240   3000.0
# 3  817800     18000  ...           3.0         57529        240   2000.0
# 4  317900   3015531  ...           1.0         05791        323   9000.0
#
#   CO_ISIC_CLASSE CO_EXP_SUBSET  \
# 0           1610         803.0
# 1           2818        1108.0
# 2           2399        3100.0
# 3           2013        1407.0
# 4            113        2399.0
#
#                                           NO_NCM_POR  \
# 0  Madeira serrada ou fendida longitudinalmente, ...
# 1          Furadeiras com motor elétrico incorporado
# 2  Outros abrasivos naturais/artificiais em pó/gr...
# 3  Outros polímeros acrílicos, em líquidos e past...
# 4                                  Melancias frescas
#
#                                           NO_NCM_ESP  \
# 0  Madera aserrada o desbastada longitudinalmente...
# 1           Taladros con motor eléctrico incorporado
# 2  Otros abrasivos nat/artif.en pol/grán.c/soport...
# 3  Los dem.polímeros acrílic.en líq.y pastas, sol...
# 4                                    Sandías frescas
#
#                                           NO_NCM_ING VL_AGREGADO
# 0  Wood sawn or chipped lengthwise, sliced or pee...        0.62
# 1          Drills with self-contained electric motor       19.48
# 2  Oth.natur/artif.abrasive powder/grain, base ot...        3.17
# 3  Oth.water-soluble acrylic polymers, in liquid/...        1.57
# 4                                  Fresh watermelons        0.73
#
# [5 rows x 36 columns]

# %%
#Calculo da FREQUÊNCIA em relação a movimentação dos produtos (NCM).
contagem_NCM = tabela_final['NO_NCM_POR'].value_counts()
total_de_ocorrencias_grupo = tabela_final.groupby(['CO_ANO', 'CO_MES', 'NO_NCM_POR']).size().reset_index(name='contagem_NCM_grupo')

contagem_NCM_df = contagem_NCM.reset_index(name='contagem_total_NCM').rename(columns={'index': 'NO_NCM_POR'})

df_merged = pd.merge(total_de_ocorrencias_grupo, contagem_NCM_df, on=['NO_NCM_POR'])

total_ocorrencias_mes_ano = tabela_final.groupby(['CO_ANO', 'CO_MES']).size().reset_index(name='total_ocorrencias_mes_ano')
df_merged = pd.merge(df_merged, total_ocorrencias_mes_ano, on=['CO_ANO', 'CO_MES'])
df_merged['FREQUENCIA'] = round((df_merged['contagem_NCM_grupo'] / df_merged['total_ocorrencias_mes_ano']) * 100, 2)

tabela_final = pd.merge(tabela_final, df_merged[['CO_ANO', 'CO_MES', 'NO_NCM_POR', 'FREQUENCIA']],
                        on=['CO_ANO', 'CO_MES', 'NO_NCM_POR'], how='left')
print(df_merged.head())
# Out:
#    CO_ANO  CO_MES                                 NO_NCM_POR  \
# 0    2022       1                   1,1,1,2-Tetrafluoroetano
# 1    2022       1           1-Cianoguanidina (diciandiamida)
# 2    2022       1  1-cloro-2, 3-epoxipropano (epicloridrina)
# 3    2022       1      2,6-Di-ter-butil-p-cresol e seus sais
# 4    2022       1    2-(Tiocianometiltio)benzotiazol (TCMTB)
#
#    contagem_NCM_grupo  contagem_total_NCM  total_ocorrencias_mes_ano  \
# 0                  15                  34                     101702
# 1                   1                   4                     101702
# 2                   1                  28                     101702
# 3                   3                  96                     101702
# 4                   1                  16                     101702
#
#    FREQUENCIA
# 0        0.01
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00

# %%
print(tabela_final.head())
# Out:
#    CO_VIA    NO_VIA  CO_ANO  CO_MES    CO_NCM  CO_UNID_x  CO_PAIS SG_UF_NCM  \
# 0       1  MARITIMA    2022       1  44071100         16      249        SC
# 1       1  MARITIMA    2022      11  84672100         11      521        RS
# 2       1  MARITIMA    2022       9  68053090         10      580        SP
# 3       1  MARITIMA    2022       1  39069019         10      493        SP
# 4       1  MARITIMA    2022       9   8071100         10      628        RN
#
#    CO_URF  QT_ESTAT  ...  CO_CGCE_N3  CO_SIIT CO_ISIC_CLASSE  CO_EXP_SUBSET  \
# 0  927800     21945  ...         240   4000.0           1610          803.0
# 1  817800        10  ...         110   2000.0           2818         1108.0
# 2  817800       392  ...         240   3000.0           2399         3100.0
# 3  817800     18000  ...         240   2000.0           2013         1407.0
# 4  317900   3015531  ...         323   9000.0            113         2399.0
#
#                                           NO_NCM_POR  \
# 0  Madeira serrada ou fendida longitudinalmente, ...
# 1          Furadeiras com motor elétrico incorporado
# 2  Outros abrasivos naturais/artificiais em pó/gr...
# 3  Outros polímeros acrílicos, em líquidos e past...
# 4                                  Melancias frescas
#
#                                           NO_NCM_ESP  \
# 0  Madera aserrada o desbastada longitudinalmente...
# 1           Taladros con motor eléctrico incorporado
# 2  Otros abrasivos nat/artif.en pol/grán.c/soport...
# 3  Los dem.polímeros acrílic.en líq.y pastas, sol...
# 4                                    Sandías frescas
#
#                                           NO_NCM_ING VL_AGREGADO  \
# 0  Wood sawn or chipped lengthwise, sliced or pee...        0.62
# 1          Drills with self-contained electric motor       19.48
# 2  Oth.natur/artif.abrasive powder/grain, base ot...        3.17
# 3  Oth.water-soluble acrylic polymers, in liquid/...        1.57
# 4                                  Fresh watermelons        0.73
#
#    FREQUENCIA_x FREQUENCIA_y
# 0          0.12         0.12
# 1          0.02         0.02
# 2          0.07         0.07
# 3          0.04         0.04
# 4          0.21         0.21
#
# [5 rows x 38 columns]

# %%
print(tabela_final.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4138724 entries, 0 to 4138723
# Data columns (total 38 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   CO_VIA          int64
#  1   NO_VIA          object
#  2   CO_ANO          int64
#  3   CO_MES          int64
#  4   CO_NCM          int64
#  5   CO_UNID_x       int64
#  6   CO_PAIS         int64
#  7   SG_UF_NCM       object
#  8   CO_URF          int64
#  9   QT_ESTAT        int64
#  10  KG_LIQUIDO      int64
#  11  VL_FOB          int64
#  12  NO_URF          object
#  13  CO_PAIS_ISON3   int64
#  14  CO_PAIS_ISOA3   object
#  15  NO_PAIS         object
#  16  NO_PAIS_ING     object
#  17  NO_PAIS_ESP     object
#  18  CO_UF           int64
#  19  SG_UF           object
#  20  NO_UF           object
#  21  NO_REGIAO       object
#  22  CO_UNID_y       int64
#  23  CO_SH6          int64
#  24  CO_PPE          float64
#  25  CO_PPI          float64
#  26  CO_FAT_AGREG    float64
#  27  CO_CUCI_ITEM    object
#  28  CO_CGCE_N3      int64
#  29  CO_SIIT         float64
#  30  CO_ISIC_CLASSE  int64
#  31  CO_EXP_SUBSET   float64
#  32  NO_NCM_POR      object
#  33  NO_NCM_ESP      object
#  34  NO_NCM_ING      object
#  35  VL_AGREGADO     float64
#  36  FREQUENCIA_x    float64
#  37  FREQUENCIA_y    float64
# dtypes: float64(8), int64(16), object(14)
# memory usage: 1.2+ GB
# None

# %%
colunas_selecionadas = ['CO_ANO','CO_MES','NO_NCM_POR','NO_UF','NO_URF','NO_VIA','NO_PAIS','VL_AGREGADO','KG_LIQUIDO','VL_FOB','FREQUENCIA_x']
tabela_final = tabela_final[colunas_selecionadas]

# %%
print(tabela_final.head())
# Out:
#    CO_ANO  CO_MES                                         NO_NCM_POR  \
# 0    2022       1  Madeira serrada ou fendida longitudinalmente, ...
# 1    2022      11          Furadeiras com motor elétrico incorporado
# 2    2022       9  Outros abrasivos naturais/artificiais em pó/gr...
# 3    2022       1  Outros polímeros acrílicos, em líquidos e past...
# 4    2022       9                                  Melancias frescas
#
#                  NO_UF                     NO_URF    NO_VIA         NO_PAIS  \
# 0       Santa Catarina           0927800 - ITAJAI  MARITIMA  Estados Unidos
# 1    Rio Grande do Sul  0817800 - PORTO DE SANTOS  MARITIMA       Nicarágua
# 2            São Paulo  0817800 - PORTO DE SANTOS  MARITIMA          Panamá
# 3            São Paulo  0817800 - PORTO DE SANTOS  MARITIMA          México
# 4  Rio Grande do Norte  0317900 - ALF - FORTALEZA  MARITIMA     Reino Unido
#
#    VL_AGREGADO  KG_LIQUIDO   VL_FOB  FREQUENCIA_x
# 0         0.62     8409167  5177394          0.12
# 1        19.48          25      487          0.02
# 2         3.17         392     1243          0.07
# 3         1.57       18000    28286          0.04
# 4         0.73     3015531  2215727          0.21

# %%
tabela_final.to_csv('tabela_final.csv', index=False)
caminho_out = '/content/drive/My Drive/FIEL LOG. - API II/ARQUIVOS BASE/'
tabela_final.to_csv(caminho_out + 'tabela_final.csv', index=False)
